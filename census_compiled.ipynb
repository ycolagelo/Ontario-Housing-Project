# %%
import pandas as pd
from pathlib import Path

# %%
filepath = Path("py-census.csv",delimiter=',', encoding="utf-8-sig")

# %%
census_df = pd.read_csv(filepath)

# %%
census_df
# Out:
#        CENSUS_YEAR           DGUID  ALT_GEO_CODE  GEO_LEVEL GEO_NAME  TNR_SF  \
# 0             2021  2021A000011124             1    Country   Canada     3.1
# 1             2021  2021A000011124             1    Country   Canada     3.1
# 2             2021  2021A000011124             1    Country   Canada     3.1
# 3             2021  2021A000011124             1    Country   Canada     3.1
# 4             2021  2021A000011124             1    Country   Canada     3.1
# ...            ...             ...           ...        ...      ...     ...
# 36829         2021     2021A000262            62  Territory  Nunavut    20.2
# 36830         2021     2021A000262            62  Territory  Nunavut    20.2
# 36831         2021     2021A000262            62  Territory  Nunavut    20.2
# 36832         2021     2021A000262            62  Territory  Nunavut    20.2
# 36833         2021     2021A000262            62  Territory  Nunavut    20.2
#
# ...

# %%
# data slicing:

canada_df = census_df.loc[census_df['ALT_GEO_CODE']==1]

# %%
canada_df
# Out:
#       CENSUS_YEAR           DGUID  ALT_GEO_CODE GEO_LEVEL GEO_NAME  TNR_SF  \
# 0            2021  2021A000011124             1   Country   Canada     3.1
# 1            2021  2021A000011124             1   Country   Canada     3.1
# 2            2021  2021A000011124             1   Country   Canada     3.1
# 3            2021  2021A000011124             1   Country   Canada     3.1
# 4            2021  2021A000011124             1   Country   Canada     3.1
# ...           ...             ...           ...       ...      ...     ...
# 2626         2021  2021A000011124             1   Country   Canada     3.1
# 2627         2021  2021A000011124             1   Country   Canada     3.1
# 2628         2021  2021A000011124             1   Country   Canada     3.1
# 2629         2021  2021A000011124             1   Country   Canada     3.1
# 2630         2021  2021A000011124             1   Country   Canada     3.1
#
#       TNR_LF  DATA_QUALITY_FLAG  CHARACTERISTIC_ID  \
# ...

# %%
ontario_slice_df = census_df.loc[census_df['ALT_GEO_CODE']==35]

# %%
ontario_slice_df
# Out:
#        CENSUS_YEAR        DGUID  ALT_GEO_CODE GEO_LEVEL GEO_NAME  TNR_SF  \
# 15786         2021  2021A000235            35  Province  Ontario     2.8
# 15787         2021  2021A000235            35  Province  Ontario     2.8
# 15788         2021  2021A000235            35  Province  Ontario     2.8
# 15789         2021  2021A000235            35  Province  Ontario     2.8
# 15790         2021  2021A000235            35  Province  Ontario     2.8
# ...            ...          ...           ...       ...      ...     ...
# 18412         2021  2021A000235            35  Province  Ontario     2.8
# 18413         2021  2021A000235            35  Province  Ontario     2.8
# 18414         2021  2021A000235            35  Province  Ontario     2.8
# 18415         2021  2021A000235            35  Province  Ontario     2.8
# 18416         2021  2021A000235            35  Province  Ontario     2.8
#
#        TNR_LF  DATA_QUALITY_FLAG  CHARACTERISTIC_ID  \
# ...

# %%
ontario_slice_df.dtypes
# Out:
# CENSUS_YEAR              int64
# DGUID                   object
# ALT_GEO_CODE             int64
# GEO_LEVEL               object
# GEO_NAME                object
# TNR_SF                 float64
# TNR_LF                 float64
# DATA_QUALITY_FLAG        int64
# CHARACTERISTIC_ID        int64
# CHARACTERISTIC_NAME     object
# CHARACTERISTIC_NOTE    float64
# C1_COUNT_TOTAL         float64
# SYMBOL                  object
# C2_COUNT_MEN+          float64
# SYMBOL.1                object
# C3_COUNT_WOMEN+        float64
# SYMBOL.2                object
# C10_RATE_TOTAL         float64
# SYMBOL.3                object
# C11_RATE_MEN+          float64
# SYMBOL.4                object
# C12_RATE_WOMEN+        float64
# SYMBOL.5                object
# dtype: object

# %%
ontario_slice_df.head()
# Out:
#        CENSUS_YEAR        DGUID  ALT_GEO_CODE GEO_LEVEL GEO_NAME  TNR_SF  \
# 15786         2021  2021A000235            35  Province  Ontario     2.8
# 15787         2021  2021A000235            35  Province  Ontario     2.8
# 15788         2021  2021A000235            35  Province  Ontario     2.8
# 15789         2021  2021A000235            35  Province  Ontario     2.8
# 15790         2021  2021A000235            35  Province  Ontario     2.8
#
#        TNR_LF  DATA_QUALITY_FLAG  CHARACTERISTIC_ID  \
# 15786     3.8              20000                  1
# 15787     3.8              20000                  2
# 15788     3.8              20000                  3
# 15789     3.8              20000                  4
# 15790     3.8              20000                  5
#
#                                  CHARACTERISTIC_NAME  ...  C2_COUNT_MEN+  \
# 15786                               Population, 2021  ...            NaN
# ...

# %%
income_slice_df = ontario_slice_df.loc[ontario_slice_df['CHARACTERISTIC_ID']==190]

# %%
income_slice_df
# Out:
#        CENSUS_YEAR        DGUID  ALT_GEO_CODE GEO_LEVEL GEO_NAME  TNR_SF  \
# 15975         2021  2021A000235            35  Province  Ontario     2.8
#
#        TNR_LF  DATA_QUALITY_FLAG  CHARACTERISTIC_ID  \
# 15975     3.8              20000                190
#
#                      CHARACTERISTIC_NAME  ...  C2_COUNT_MEN+  SYMBOL.1  \
# 15975      Under $5,000 (including loss)  ...       604555.0       NaN
#
#       C3_COUNT_WOMEN+  SYMBOL.2 C10_RATE_TOTAL  SYMBOL.3 C11_RATE_MEN+  \
# 15975        614330.0       NaN           14.9       NaN          14.4
#
#        SYMBOL.4 C12_RATE_WOMEN+  SYMBOL.5
# 15975       NaN            15.5       NaN
#
# [1 rows x 23 columns]
